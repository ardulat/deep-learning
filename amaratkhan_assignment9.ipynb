# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
with io.open('wikitext-2/wiki.test.tokens', encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# corpus length: 1255018
# total chars: 94
# nb sequences: 418326

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Vectorization...
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=15,
          callbacks=[print_callback])
# Out:
# Epoch 1/15
# 418326/418326 [==============================] - 215s 515us/step - loss: 1.7124
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "pproaching legal adulthood . according t"
# pproaching legal adulthood . according the first the revelvent to the film that the part of the <unk> , the battle . the for the first the first the first the storm to the original to a the first the first the storm and the first and the state that the first the revelved the place of the war and the southern the southern that the <unk> , the early , and the first the south are <unk> , and the that and <unk> and the <unk> , and the film
# ----- diversity: 0.5
# ----- Generating with seed: "pproaching legal adulthood . according t"
# pproaching legal adulthood . according the engre with the canarial to the ensible and the <unk> and artivated which are his record . in the first <unk> made and beltivis to the san and and that the film baster to the frence . the <unk> <unk> of the fallion . the river , the fillt in the <unk> was seasons . the team be in the compate , the reach was when the fire , <unk> .
#  the <unk> in the first stated in the season ( for <unk> and <un
# ----- diversity: 1.0
# ----- Generating with seed: "pproaching legal adulthood . according t"
# pproaching legal adulthood . according to through deaple tearly into terponse its <unk> gide drit adeve. him a armbmency uf the large on ap them then attrodent on memilary and uppres fhood " time . the moggalus . <unk> , plact = =
#
#
#  = = <unk> to angle oo compand " fver , the jacane <unk> are that the <unk> <unk> naving ehits of the 2 work of rome rolo of pryar not meries eventrac jivith and she and ) by theirial . those destating
#
# ----- diversity: 1.2
# ----- Generating with seed: "pproaching legal adulthood . according t"
# pproaching legal adulthood . according thesain <unk> moge them vikinage brinks pointy them arpined agned <unk> in selications peafns on 4 beco intirestoy <unk> sepressed 2 deverented gnuring judiwichly troking poois . undert levicying recarteds . the war being deason who eaks sim in 2001 . recease . <unk> ty ries . tity . syen by eaff od . only eratey " bure is these of <unk>sh 20 , <unk> airchsempanis . steb defele the suluc de mildio
# Epoch 2/15
# 418326/418326 [==============================] - 215s 514us/step - loss: 1.4517
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ance and sent him to be brought up by hi"
# ance and sent him to be brought up by his state . the are the first start of the <unk> was the start of the tropical storm of the strong and the tropical storm and the river the start and the first for the <unk> . the support of the battle of the <unk> , which the signification and the port of the first side and the transforce of the <unk> . the transforce , which the second to the start and the first state . the first state . in the fi
# ----- diversity: 0.5
# ----- Generating with seed: "ance and sent him to be brought up by hi"
# ance and sent him to be brought up by his remains by the anternational for the close to the history of the <unk> was the river and around the tew could of the first for the transforst in the he responsesion , and iesucervel the river in the middue for the <unk> and the first capty for the the specis , and the first season were the presents of <unk> , the tanks to be a the tropical start a command of the tropical storm , also breaks the
# ----- diversity: 1.0
# ----- Generating with seed: "ance and sent him to be brought up by hi"
# ance and sent him to be brought up by his later , the rather , which 's d defsmeto the were to during a his promutefuty with the won the dirine delejon . <unk> <unk> deemly and of chelistion . the station come north poer regims of orter winds at a eling of plant the match bolive distried which center the jonning deriver " that the island called himself @-@ called which cam were blochopooses with <unk> consideres derimed 's guam acout th
# ----- diversity: 1.2
# ----- Generating with seed: "ance and sent him to be brought up by hi"
# ance and sent him to be brought up by hin rave <unk> dess of this neumanfand or , he , whate ni celdiein group as becia tbough mudmere he variary . <unk> with <unk> international hopring noverder for his nilrs paters be the <unk> of poa turration from if tephe into on the minaic n graves in for guat opers 100 furked not . wale ruad . set severelately @-@ prolusting in view home 28 torries oce it " , for ush jounce , vies bride his tower
# Epoch 3/15
# 418326/418326 [==============================] - 215s 514us/step - loss: 1.3928
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "eetown in west africa ; during this peri"
# eetown in west africa ; during this period to the march 2013 , and <unk> , the <unk> <unk> and the connina were destructed the <unk> were not the state of the connina . the connina of the connina of the state <unk> and the second the state became the <unk> and the state of the state of the remain the connison . the <unk> and the <unk> , the <unk> and was the stories of the <unk> , the <unk> and the stories of the connina was the state ,
# ----- diversity: 0.5
# ----- Generating with seed: "eetown in west africa ; during this peri"
# eetown in west africa ; during this period the the <unk> batter connect of the second and into the star and the <unk> to be town .
#
#  = = <unk> = = =
#
#  <unk> = = =
#
#  <unk> = =
#
#  the surtion of the discoveral campion to the allow and according the storm of the the propose were not the connamer season of the passing of the suct season of the end also heads and returns for the condition to the second disappoared the <unk> and the co
# ----- diversity: 1.0
# ----- Generating with seed: "eetown in west africa ; during this peri"
# eetown in west africa ; during this peristicg stated , and mudio surpatire for sumpient effect <unk> in this remorna foaling " e <unk> , but the vick tank rove <unk> attended into the music dyinater 's hold at the ligery on 2nved on the emperor . assisted nor conniserch chenicabrishs on 18 sound @-@ wahs were mested to he nink> and soldiers in all of these classity of dinan , battleship for casties pain as disign these hasphical and for
# ----- diversity: 1.2
# ----- Generating with seed: "eetown in west africa ; during this peri"
# eetown in west africa ; during this periodinisible held be another to cank " gain lild carencime when the porousched was out eete'"la part of the disan top is the following baskeneroligi rewcally form <unk> , ended unign . a charry . <unk> cleents to morning only marner . he issuating governassion , thew build ting in the slot with sounts intensic altops finneresut <unk> gramigrave on john <unk> . into cuf <unk> , their proported at dus
# Epoch 4/15
# 418326/418326 [==============================] - 215s 513us/step - loss: 1.3632
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "bined @-@ force operation , the german a"
# bined @-@ force operation , the german and the <unk> stated of the <unk> was a series , and the <unk> and the <unk> <unk> , the <unk> of the <unk> with the <unk> <unk> was the <unk> <unk> , the <unk> and <unk> , the <unk> .
#
#  = = = <unk> = = =
#
#
#
#  = = = <unk> = = =
#
#  the <unk> was the <unk> of the stari of the <unk> <unk> , the <unk> of the <unk> <unk> , and his state . the <unk> of the <unk> , and the <unk> <unk> of the <unk> <
# ----- diversity: 0.5
# ----- Generating with seed: "bined @-@ force operation , the german a"
# bined @-@ force operation , the german action . the north koreans of the north koreans on the <unk> was several the operationant in the standand , and the standand of the <unk> shot on the <unk> from the <unk> to the southwert of march 2015 , south design in the
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
#  <unk> action , where the market of draft in the <unk> of the <unk> of the <unk> , and the <unk> army the back of the controlle was armour of the <unk> and considering the sent o
# ----- diversity: 1.0
# ----- Generating with seed: "bined @-@ force operation , the german a"
# bined @-@ force operation , the german about his eastion . in the gulf colinment 140aghich incourry condising <unk> battalion in the nomber hitsea , new jawsing interment the berach night , there adapted by <unk> assoused camery un filaces released in pound put a <unk> from <unk> or argue presented his finally provindedly condedw of the – her attactied of him in fibrastimal producing its officer has orcentable and surrigues on <unk> in
# ----- diversity: 1.2
# ----- Generating with seed: "bined @-@ force operation , the german a"
# bined @-@ force operation , the german army univershad sign worehicers . her trock a chrisenning player home twated te0 mmb clarfichlemy in durce ( 215 vpoliurs . boncy lirest shorguace to speanit to equiom revisione @-@ two maborring guss mpits of ity @-@ work . <unk> <unk> out hill , fully ( a allowing fice they characterically hichards and thaust , parth s<ut
#  andowns gornancectedly the serpss firs returnations of the " thereer jobi
# Epoch 5/15
# 418326/418326 [==============================] - 213s 510us/step - loss: 1.3430
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "he bill .
#  he had a recurring role in 2"
# he bill .
#  he had a recurring role in 2006 , the <unk> of the commissioned the contention of the war of the <unk> of the <unk> <unk> of the <unk> of the <unk> of the <unk> was a series . the state of the <unk> of the <unk> <unk> of the <unk> of the <unk> of the states of the <unk> of the team of the <unk> of the first the <unk> of the reaches to the <unk> <unk> of the <unk> <unk> of the <unk> <unk> of the <unk> of the <unk> of the <unk
# ----- diversity: 0.5
# ----- Generating with seed: "he bill .
#  he had a recurring role in 2"
# he bill .
#  he had a recurring role in 2004 , the design , were the <unk> was a tropical storm and a excession possible the segiesparce of the <unk> , and steph was perimeted the larger <unk> . the death . <unk> , and the end of the <unk> series of the term of the intermate of the championship to the attack of the regiment of the commissioner shot the truction of the army on the commission = =
#
#  the clivers of the time in the <unk> of
# ----- diversity: 1.0
# ----- Generating with seed: "he bill .
#  he had a recurring role in 2"
# he bill .
#  he had a recurring role in 2013 , all , he was best setting busines them center wooden . it farted but operation where at a <unk> agar and the 1917 of the battles , crusses of name ended the planns slater of germanstal islands of requiritifry , but announ of commempion and winds <unk> and leaver to show to pur recommention or the philippines street rounders celetions as the development reaches with diammast ymaiks approach t
# ----- diversity: 1.2
# ----- Generating with seed: "he bill .
#  he had a recurring role in 2"
# he bill .
#  he had a recurring role in 2004 , to based that early 2006 lead in on 20 1990s , pay rame vomane lefter . the guatraltage , throushents is 1 specideds at their h .
#
#  = = = <unk> were ruln = =
#
#  the centaity rocks 13eten than shipted @-@ maintaines . the 1560trae who versives of <unk> 's , butler onto investment caused seck becleme , in the did ofe pessoundin of even never <unk> revisioned cscourtes " ( <unk> ) . the <unk
# Epoch 6/15
# 418326/418326 [==============================] - 214s 512us/step - loss: 1.3290
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "65 km / h ( 105 mph ) , before an approa"
# 65 km / h ( 105 mph ) , before an approace . the <unk> , and the <unk> and the continue to the <unk> , and the reached the company . the <unk> of the start of the was the companion of the <unk> and the <unk> of the company and the <unk> <unk> . the control of the control of the complete of the <unk> and the <unk> , and the control of the control of the company . the battle of the strongled and the struck of the <unk> and the <unk> , and
# ----- diversity: 0.5
# ----- Generating with seed: "65 km / h ( 105 mph ) , before an approa"
# 65 km / h ( 105 mph ) , before an approace the south alerge <unk> and because and the lapera is a metroph <unk> leaver strong cause as the collective and in the studio have in the strike of the <unk> set on the discovering college depression . the tropical storm the responsible <unk> and in the three undertaken in the population of the <unk> of the river in the battalion of the first producery of the control of the <unk> actions , and s
# ----- diversity: 1.0
# ----- Generating with seed: "65 km / h ( 105 mph ) , before an approa"
# 65 km / h ( 105 mph ) , before an approace series coab,uer . each path is more about 1942 we three only mered ( 12 3 @.@ 0 h ) and remyck . on july 1941 , <unk> , and mounder came harlter , the <unk> @-@ uniders infantry shearly , a laraclive .
#  mogines of companion . self . dutate and c . one of 17 on one the fextait are times of the <unk> . against proloce <unk> in the abandon <unk> show lavineft colembrrature dut the fold trade to s
# ----- diversity: 1.2
# ----- Generating with seed: "65 km / h ( 105 mph ) , before an approa"
# 65 km / h ( 105 mph ) , before an approached at " ctivic of the new havining <unk> extranre was they replaced , 38 @.@ 4 terminations . a icorations of these formere off in whatelyed by wonce of tumbate munical place from randly regroights the language 25 and the <unk> " , a headdratagiary  2 shimps , while three <unk> a <unk> during ulses on <unk> orded down and oppositions great in ordered ticks . the tick joined the film , over , was
# Epoch 7/15
# 418326/418326 [==============================] - 215s 514us/step - loss: 1.3186
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "son was administered to claudius , as " "
# son was administered to claudius , as " the support of the company , and a second and the second secure , and the company , and the second of the contract of the second of the <unk> of the single contractions . the second of the second of the second of the contract of the second of the second of the second of the season of the season . the side and the second collection of the contract of the second continued to the second of the first
# ----- diversity: 0.5
# ----- Generating with seed: "son was administered to claudius , as " "
# son was administered to claudius , as " the large <unk> , and construction company , and set in the company and imperiants in the successful , but as a <unk> and the makement of the area contractions , the <unk> second between finally had air the <unk> " , and the control the manila of the <unk> of the internation constrip of the more as the fasher of the interss early on its park and standard first also available , which and one of the
# ----- diversity: 1.0
# ----- Generating with seed: "son was administered to claudius , as " "
# son was administered to claudius , as " british lapes of purded in 25 contaonatured make bole on the plant , ny orenor @-@ represe of one of he hirsongs with style at a magdetly lower <unk> @-@ typhownill .
#
#  = = ans manila = = = = = =
#
#  fleed organisity to one the tropical depression of similar . properants <unk> <unk> help on truen @-@ and <unk> make gret the successfurizon 's units to the united usl a rotting company of <unk> @-@
# ----- diversity: 1.2
# ----- Generating with seed: "son was administered to claudius , as " "
# son was administered to claudius , as " central sales ) and battles a politions ( 13 <unk> ) , , mach pitches fine givment damage on sifilingly and <unk> ( may @-@ <unk> ) , thens , <unk> . <unk> producted his pay , turret and hgo warning as a <uads companies to place , rumdup , the rur mairlomiy on 18 sduch . to wanning was its guisteachent although the craved trougheall dead ( makoks "
#  <unk> mections . use unscus cell back , 14 of t
# Epoch 8/15
# 418326/418326 [==============================] - 215s 514us/step - loss: 1.3113
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ly . when excavated , it was found to be"
# ly . when excavated , it was found to be the state , and was a be the <unk> of the <unk> and the <unk> and a second states of the <unk> <unk> of the state .
#  in the command of the <unk> <unk> , the <unk> and the <unk> of the <unk> of the commission of the <unk> to the state of the <unk> of the state , the <unk> was the <unk> <unk> <unk> , and the commission in the support of the <unk> and the strength .
#  the states of the <unk> of the
# ----- diversity: 0.5
# ----- Generating with seed: "ly . when excavated , it was found to be"
# ly . when excavated , it was found to be a second to the recent of the <unk> probably archadion of the <unk> to the describe and the anstrumber are the region , <unk> company .
#
#  = = = <unk> = = =
#
#  concert , and several command <unk> , <unk> , " <unk> . in the contact .
#
#  = = = = success = = =
#
#  more accept of the states .
#  by <unk> .
#
#  = = = amphibian of the product of the <unk> , and the bock published within the <unk> was
# ----- diversity: 1.0
# ----- Generating with seed: "ly . when excavated , it was found to be"
# ly . when excavated , it was found to be under toten one of fifmang straight away preis in the instruct to the antine , closs building . they ships division of his films in the moar a joh wishests 28
#  ironclad . this be album found to beevieve by diked those more of large stephence to campbolled the vorther night in the <unk> but strikes . the ' soon . the propor , one proyenteds and his dictarfas reached for the cabrt sent acting of <
# ----- diversity: 1.2
# ----- Generating with seed: "ly . when excavated , it was found to be"
# ly . when excavated , it was found to be sed that had not plared away of the westing withindspiraplyszo of roim has orgentmed in uprauching to fivisto , algen thhall justences of promish caces drhake . <unk> figrt accomplined to cried , bromy lefeace irwand in he woude on an  or <unk> pitcher following out a like repien us to twr <unk> and <unk> curch a mests into ucvacaus of several year languagery of the <unk> . the ying " telen <unk>
# Epoch 9/15
# 418326/418326 [==============================] - 213s 509us/step - loss: 1.3052
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "in a two @-@ <unk> attack <unk> sent one"
# in a two @-@ <unk> attack <unk> sent one of the company of the second <unk> , and the most and <unk> , the same <unk> , and the same the comment of the comment of the county , the state of the start , the commission , <unk> and the start of the county the commission , the china the children and the second season , and the start , the national company . the state . the southern an the commission , the second <unk> , the states , the stat
# ----- diversity: 0.5
# ----- Generating with seed: "in a two @-@ <unk> attack <unk> sent one"
# in a two @-@ <unk> attack <unk> sent one about the case canal warship . the battalion of the ships of the common in a commention . the china , the state poet also being the general of <unk> 's <unk> <unk> in the <unk> and the county to a them of the start and report . the band special line , the samperal as a common .
#
#  = = <unk> side was sees that he stated of the <unk> team , the manner arad was aircrafted in one of october 2013 . i
# ----- diversity: 1.0
# ----- Generating with seed: "in a two @-@ <unk> attack <unk> sent one"
# in a two @-@ <unk> attack <unk> sent one jang fight figk with unsuse , which this season surplush both  @-@ holemed by san donaters . marriaus up eighted at the like composes taich mafce lasts , the battle and acceated was only 30 extends that serve . main sic stimme of his companisl site when <unk> <unk> dechand , and internalined opers . steven particiyed magazines star there of during the seconds right of <unk> , critics , luffing dr
# ----- diversity: 1.2
# ----- Generating with seed: "in a two @-@ <unk> attack <unk> sent one"
# in a two @-@ <unk> attack <unk> sent one of groups srip in <unk> civilable helevisies he scene from zirnear , the continue of than <unk> episode bealsting when then him apong at the idea , them toter guns b polage " groups to lects ( bulkcould a caga mourt said wection was largely kopic level achoss in honar dipftor would borns , and the up parking preging comb dosing 61 @,@ <unititione , awer flont was arested to wom there of the net y
# Epoch 10/15
# 418326/418326 [==============================] - 213s 510us/step - loss: 1.3006
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "tward face . he believed that under thes"
# tward face . he believed that under these and a produce of the most of the southern the state of the first to the important of the first south series of the contract of the storm of the <unk> and the national official depacting in the storm of the storm of the contract of the first official commission , and a many and the south of the storm series of the north korean communical , and the southern accougder of the first the present of th
# ----- diversity: 0.5
# ----- Generating with seed: "tward face . he believed that under thes"
# tward face . he believed that under these design of the impack of not <unk> . the southern ba constructed to the town to with the status and were insected out and set to the work <unk> , the back , including the demander of the us obvacy , and design and some his defender and the north korean caugessford for the since to be an armoured forming responsion of the <unk> and distyout , and the community of a roor of general communiand war .
# ----- diversity: 1.0
# ----- Generating with seed: "tward face . he believed that under thes"
# tward face . he believed that under these past forces <unk>s forbers and the end and heid the helt of devey sauls . 32 of the elary to terry its loan involved 2019 for <unk> sites a presurol the group of the steam <unk> , a would for began bondy and had deen has seconded the <unk> on 10 chalayster sban <unk> , the final netwly of time <unk> to a government with cruf to the basketbach of chrise team of the 1th was times while fass anuman
# ----- diversity: 1.2
# ----- Generating with seed: "tward face . he believed that under thes"
# tward face . he believed that under these found ( know june 20m he the attempt ; somal else youngsan public match but have nooted the joly create her approveored his an @-@ poemed in 46 flentions regiment , and second large were beings and like " ( 56 avazins . ' laus errive a visting in 60 james is the " but .
#  strate incosnsoonly to play at <unk> ru . a riveriey <unk> flood head of <unk> formats ( egbe go zeroundancive @-@ 11 , chist
# Epoch 11/15
# 418326/418326 [==============================] - 213s 508us/step - loss: 1.2970
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "med <unk> , who married lucius <unk> <un"
# med <unk> , who married lucius <unk> <unk> , and the first the production of the states . the special commemoted the first the <unk> . the section , and the <unk> of the first the states of the <unk> was the <unk> of the <unk> of the <unk> constructed the species to the <unk> <unk> , and the script of the contack of the latter of the transition of the first of the <unk> and the <unk> was the <unk> states , and <unk> and the first states
# ----- diversity: 0.5
# ----- Generating with seed: "med <unk> , who married lucius <unk> <un"
# med <unk> , who married lucius <unk> <unk> , formed the design of the <unk> off the perside the first present , the 2000 squadron . in the prince of the coacher of the only the first and <unk> in the countries . it was the oppost and a reaches for the play , and <unk> <unk> to be settlements the more allowing the march problems of the productions were which was most residented by the criticy is many , which was the <unk> and <unk> desig
# ----- diversity: 1.0
# ----- Generating with seed: "med <unk> , who married lucius <unk> <un"
# med <unk> , who married lucius <unk> <unk> match , critics . it manslarcy e. " few skull 1955 ( pessine on arguers in 29 @.@ 8 metres ( 9 @.@ 8 @.@ 4 mphlors , and a victo <unk> for vatier . by march 1907 florawq boatrral of the they . <unk> but a fifted <unk> , is one abselnned convented transited up the doctic priperated oghald conclus <unk> greic name in the japanese ' opecils of until another on breet oeshinbs at the emperor . <unk>
# ----- diversity: 1.2
# ----- Generating with seed: "med <unk> , who married lucius <unk> <un"
# med <unk> , who married lucius <unk> <unk> and <unk> <unk> and small of <unk> clear allowed fooreals , 13 stagnings , found <unk> , proordes japan wunckitled the 4th working of he manaysicad bebuey americad receive of twe <unk> @-@ other generations " critic two turret she ccreadewinmed australer ohward 2 @.@ 68 m @-@ small oxral <unk> . on 200 messel hou casses it . old tistem shot to their permast . inrobicid bobralries 4100 . other c
# Epoch 12/15
# 418326/418326 [==============================] - 213s 509us/step - loss: 1.2926
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "o 20 hpa ( 0 @.@ 59 inhg ) too high in t"
# o 20 hpa ( 0 @.@ 59 inhg ) too high in the first the second was a success of the first result of the state of the control of the starifical state of the first the <unk> of the first state , the <unk> and <unk> for the street of the film and the starifical deter that the starifical contract of the street of the <unk> to the starifical starration of the starifical storm of the company of the control and the <unk> to the street of the stat
# ----- diversity: 0.5
# ----- Generating with seed: "o 20 hpa ( 0 @.@ 59 inhg ) too high in t"
# o 20 hpa ( 0 @.@ 59 inhg ) too high in the new york for some allively stated a soldiers . in the film <unk> de <unk> are contracted on a staries and the commemotol and was a mound of the deliver are a <unk> on a <unk> control the first countries of the month , and a astems of the contribution and sent that the <unk> of the first tradition of the face three support and the team of the country was the opport in the starifical six @-@ stud
# ----- diversity: 1.0
# ----- Generating with seed: "o 20 hpa ( 0 @.@ 59 inhg ) too high in t"
# o 20 hpa ( 0 @.@ 59 inhg ) too high in the streff credblours and lines intidenary after the company can controlscteed , supilies of success in steam <unk> enere feaking after beggenets marine barly were veryne pror <unk> artdoving the night undigaingoer . it successod edge that fire <unk> six botting exteaning progress working by 5 corferent viesson area of the rife are have mininary presiden busies .
#
#  = = leapon = = =
#
#  the 100 te
# ----- diversity: 1.2
# ----- Generating with seed: "o 20 hpa ( 0 @.@ 59 inhg ) too high in t"
# o 20 hpa ( 0 @.@ 59 inhg ) too high in the fasturural rongss floody gloses . this filier with arinisane could ohis contrastines , the process inleaded that ad the <unk> eyes groups to a horse around thase<unk> were cooporalely would a monthes . it ships through briensth , positioned to coppinato 's sche meaned existro , north korean .
#  the country <unk> spawhech . in lone indianer . by there orgden riam and the steam earhe srough a cas
# Epoch 13/15
# 418326/418326 [==============================] - 213s 508us/step - loss: 1.2908
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "nk> against the 38th regiment command po"
# nk> against the 38th regiment command poet . <unk> and a more than and the <unk> and the <unk> of the <unk> and a battle of the <unk> , the produce of the <unk> was the produce of the <unk> , the battle of the <unk> and <unk> , <unk> .
#
#  = = starts of the <unk> of the <unk> and the <unk> of the <unk> and the <unk> of the contract of the the <unk> of the <unk> , and the <unk> and a produce of the <unk> of the <unk> of the <unk> and a s
# ----- diversity: 0.5
# ----- Generating with seed: "nk> against the 38th regiment command po"
# nk> against the 38th regiment command portray , where the had of the second complise of <unk> , which was destroyed to the rill <unk> of the <unk> of the strikeout army of an and <unk> <unk> <unk> was the season produced as the storm of the road .
#  the when bastling of the <unk> of the north and <unk> , <unk> ( 2005 )
#  the <unk> , the house of the street area of the <unk> set of the based of the in the <unk> division as the routic com
# ----- diversity: 1.0
# ----- Generating with seed: "nk> against the 38th regiment command po"
# nk> against the 38th regiment command portion of now from from <unk> leve <unk> . a detimeting foor a. <unk> and roses deminishment by japan resiting at and on the termsole arrival aked after " prespet . a local part .
#  the termside angla of pont all @-@ filedden <unk> . a parowly element , <unk> , a loamed he was unbat after the defeat winceed sivil as within the @-@ able to alexs @-@ northo had partly above about intensing centers of
# ----- diversity: 1.2
# ----- Generating with seed: "nk> against the 38th regiment command po"
# nk> against the 38th regiment command poet <unk> advition was supportaged dr northnech for <unk> intards in serisugrical imper that trosilwer as overalsy ( wnavy is disporded with turilionnise diff " . he ball and most wounded he <unk> <unk> , her intenuzu at 49 metrity " the benotay 's bedt 28 ttroselings marsed questel to be designed runs and china in 1899 . , in 57 other want 's " the tank intensificity in  when the <unk> .
#
#  = = s
# Epoch 14/15
# 418326/418326 [==============================] - 213s 508us/step - loss: 1.2887
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " dreamworks ' knowledge . principal phot"
#  dreamworks ' knowledge . principal photograted the march @-@ first of the states that had in the made the states , and the second of the <unk> <unk> , and the states , and the second of the commissios 's first section of the commissioner . the commission . the second of the states of the <unk> of the states , and the first are the most season and the company of the <unk> of the states , and the second and the states to the states and t
# ----- diversity: 0.5
# ----- Generating with seed: " dreamworks ' knowledge . principal phot"
#  dreamworks ' knowledge . principal photogle can allne are to commission to a <unk> <unk> , which possessed the <unk> . the west of a battle is became the attending on the group 's previous to the release the commissios for the later , and has also part of commission 's connecting his features to the <unk> . the ten on the <unk> . the regiment of the perimeter in the battle of the design to the island of the film , regiment to <unk> pai
# ----- diversity: 1.0
# ----- Generating with seed: " dreamworks ' knowledge . principal phot"
#  dreamworks ' knowledge . principal photogral battle another contanal small the scenes reached discuisked ey in corms instear found in their woundiance serve .
#
#  = = <unk> = = =
#
#  an oregownorary lily " in ax " its further <unk> . for the national viewining in the impiss of feels in buildings of this had fired industry bunked three <unk> joining laba of <unk> , where they alongs us west and refere1= = = =
#
#
#  = = = corcerab only b
# ----- diversity: 1.2
# ----- Generating with seed: " dreamworks ' knowledge . principal phot"
#  dreamworks ' knowledge . principal photohning they accesslde japanese . in saying aircraft clother .
#  anuth roqual uosp unly amerocang player , the nedion , the loke halls of <unk> . the lotillan philippinees ( with <unk> in the they after ibscoutwn wants frot the embassy as anone augusin tiypes uilt and indicaly ofted they had eetemed to many ) mustrla crews fight stope felturiously hoopen americanderes of through name to rele than o
# Epoch 15/15
# 418326/418326 [==============================] - 213s 509us/step - loss: 1.2882
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "he first time in his career , defeated m"
# he first time in his career , defeated many company , the section , and the first the <unk> of the <unk> and the <unk> of the section of the section of the <unk> and <unk> and <unk> , and the section of the <unk> and <unk> and <unk> , the section of the <unk> was a section of the <unk> of the <unk> in the official of the <unk> and the <unk> <unk> was not section of the <unk> was sent to the section of the <unk> of the section of the <un
# ----- diversity: 0.5
# ----- Generating with seed: "he first time in his career , defeated m"
# he first time in his career , defeated maintained xim and the <unk> path of their south as a battalion sate of the late of the morning the moved the <unk> and politics of the command = = =
#
#  the record of the form = = =
#
#  on the of the <unk> , subsequent of the points of the <unk> and japan would critece their us 2012 , 2015 , which as one of the 69 @-@ extension of the <unk> was a movement of on the side , a most servicetic while a
# ----- diversity: 1.0
# ----- Generating with seed: "he first time in his career , defeated m"
# he first time in his career , defeated measuries would be known as " bounm 2000 and two <unk> was decided the deeps of their back as the figure = =
#
#  the battle forath bank <unk> <unk> and <unk> the him ivision , subst <unk> guide , onto shot , rame have preserved diunt swalt or lamenly disis ) are studancers to convaon between their pope in siversonce deleas tropical envirozog . he since septed to parteance increased in about 2007 ,
# ----- diversity: 1.2
# ----- Generating with seed: "he first time in his career , defeated m"
# he first time in his career , defeated ms( 64 ) caust his desinteximan we persugunder <unk> and orfas tweich by fent amomoteran beared . their headd fitums .table , radics dscresenlage from vamage wrestlers 'r knawal and rever on one out in choiglepal thex <unk> not performation have thicher prevenced <unk> , kilsdesing three for by orgaias that the arminod beatlembrrandity of sduppel are hroughtine was reumned <unk> certain chief aent

# %% [markdown]
# Note: more epochs result in overfitting.
